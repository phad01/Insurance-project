# %% [markdown]
# # Data Exploration or Wangling

# %%
# Importing library
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
V_insurance = pd.read_csv("Vehicle claim insurance data.csv")     # reading files

# %%
V_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  object
#  2   Policy End Date         12079 non-null  object
#  3   Gender                  11720 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            8341 non-null   object
#  8   Subject_Car_Colour      5117 non-null   object
#  9   Subject_Car_Make        9603 non-null   object
#  10  LGA_Name                5603 non-null   object
#  11  State                   5591 non-null   object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %%
V_insurance
# Out:
#             ID Policy Start Date Policy End Date  Gender  Age  \
# 0      0040R73        2010-05-14      2011-05-13    Male   30
# 1      0046BNK        2010-11-29      2011-11-28  Female   79
# 2      005QMC3        2010-03-21      2011-03-20    Male   43
# 3      0079OHW        2010-08-21      2011-08-20    Male    2
# 4      00BRP63        2010-08-29      2010-12-31  Entity   20
# ...        ...               ...             ...     ...  ...
# 12074  ZZA1SES        2010-05-25      2011-05-24  Female   30
# 12075  ZZDAC3K        2010-10-03      2011-10-02  Female   59
# 12076  ZZIU2XC        2010-10-10      2011-10-08    Male   34
# 12077  ZZRQ1NF        2010-02-27      2011-02-26     NaN  120
# 12078  ZZWRIIE        2010-07-01      2011-06-30  Female   46
#
#       First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0                 2010-05-14       1       Saloon              Black
# 1                 2010-11-29       1         JEEP               Grey
# ...

# %%
V_insurance["Gender"].unique()
# Out:
# array(['Male', 'Female', 'Entity', 'Joint Gender', nan, 'NO GENDER',
#        'NOT STATED', 'SEX'], dtype=object)

# %%
V_insurance["Car_Category"].unique()
# Out:
# array(['Saloon', 'JEEP', nan, 'Motorcycle', 'Truck', 'Bus', 'Mini Bus',
#        'Pick Up', 'Mini Van', 'Van', 'Pick Up > 3 Tons', 'CAMRY CAR HIRE',
#        'Wagon', 'Shape Of Vehicle Chasis', 'Sedan', 'Station 4 Wheel',
#        'Tipper Truck'], dtype=object)

# %%
V_insurance["Subject_Car_Colour"].unique()
# Out:
# array(['Black', 'Grey', 'Red', nan, 'As Attached', 'Blue', 'Silver',
#        'Green', 'Ash', 'White', 'Gray & Gray', 'Wine', 'Brown',
#        'Red & Blue', 'Gold', 'Gray & Silver', 'Orange', 'Red & Black',
#        'Dark Grey', 'White & Red', 'Light Green', 'Dark Gray', 'B.Silver',
#        'Purple', 'Blue & Red', 'Red & Yellow', 'Yellow', 'Red & White',
#        'D. Red', 'Dark Red', 'Black & White', 'White & Blue', 'Cream',
#        'Dark Green', 'D. Gold', 'Champagne', 'Light Blue',
#        'Blue&White&Red', 'White & Yellow', 'Dark Blue', 'Black & Orange',
#        'Burgundy', 'Yellow & White', 'Beige Mitalic', 'Light Gray',
#        'Blue Sky'], dtype=object)

# %%
V_insurance["Subject_Car_Make"].unique()
# Out:
# array(['TOYOTA', nan, 'REXTON', 'Lexus', 'Hyundai', 'Iveco', 'DAF',
#        'Honda', 'Mercedes', 'Jincheng', 'ACURA', 'Ford', 'Volkswagen',
#        'Nissan', '.', 'Pontiac', 'Range Rover', 'Kia', 'Mitsubishi',
#        'Scania', 'BMW', 'Infiniti', 'Renault', 'Volvo', 'Hummer', 'Mack',
#        'Grand Cherokee', 'Porsche', 'Peugeot', 'Land Rover', 'Chevrolet',
#        'Mazda', 'Man', 'Jeep', 'Audi', 'Suzuki', 'MINI COOPER', 'KA',
#        'As Attached', 'Innson', 'Isuzu', 'Skoda', 'Jaguar', 'Chrysler',
#        'Dodge', 'GMC', 'Land Rover.', 'Subaru', 'GAC', 'Fiat', 'Opel',
#        'Astra', 'Motorcycle', 'ZOYTE', 'Seat', 'FOTON', 'Howo', 'Lincoln',
#        'Rols Royce', 'CHANGAN', 'LIBERTY', 'ABG', 'Yamaha', 'Black',
#        'Tata', 'Ashok Leyland', 'Geely', 'Caddillac', 'Wrangler Jeep',
#        'Raston', 'MG', 'BRILLIANCE', 'Buik', 'COMMANDER', 'Bajaj'],
#       dtype=object)

# %%
V_insurance["LGA_Name"].unique()
# Out:
# array([nan, 'Lagos', 'Ikeja', 'Badagry', 'Eti-Osa', 'Victoria Island',
#        'Ikoyi', 'Lagos Mainland', 'EFFURUN', 'Abeokuta',
#        'Abuja Municipal', 'Yaba', 'Aguda', 'Surulere', 'Oshodi-Isolo',
#        'Alimosho', 'Okpe, Delta State', 'Asaba', 'IbadanCentral', 'Lekki',
#        'Ibeju/Lekki', 'OBANIKORO', 'Agege', 'ISHERI', 'Kosofe', 'OGUN',
#        'Apapa', 'Ibadan South West', 'Obia/Akpor', 'Ibadan South East',
#        'Sapele', 'Kaduna South', 'Ikorodu', 'Amuwo-Odofin', 'Awka',
#        'GBAGADA', 'Port Harcourt', 'Minna', 'Shomolu', 'Benin',
#        'Lagos Island', 'Central', 'Ebute-Metta', 'Ketu', 'Uyo', 'Mushin',
#        'Katagum', 'ENUGU EAST', 'Oredo', 'Abuja', 'Festac', 'Ipaja',
#        'Zaria ', 'Esan West', 'Oluyole', 'Bwari', 'Obafemi-Owode', 'LGA',
#        'Orile-Iganmu', 'Egbeda', 'Ido', 'Ifako-Ijaye ', 'Ibadan North',
#        'Oguta', 'Jos North', 'Ajah', 'Ondo West', 'Kaduna North', 'Warri',
# ...

# %%
V_insurance["State"].unique()
# Out:
# array([nan, 'Lagos', 'Benue', 'Eti-Osa', 'Delta', 'Ogun',
#        'Abuja-Municipal', 'Oshodi-Isolo', 'Ibeju-Lekki', 'Ibadan-West',
#        'Obia-Akpor', 'Ibadan-East', 'Kaduna-South', 'Amuwo-Odofin',
#        'Anambra', 'Rivers', 'Niger-State', 'Edo', 'Akwa-Ibom',
#        'ENUGU-EAST', 'Abuja', 'Kaduna', 'Esan-West', 'Obafemi-Owode',
#        'Orile-Iganmu', 'Ifako-Ijaye', 'Ibadan-North', 'Imo', 'Jos-North',
#        'Ondo-West', 'Kaduna-North', 'Aniocha-South', 'Awka-South',
#        'Ile-Oluji', 'Ijebu-Ode', 'Port-Harcourt', 'Nnewi-North',
#        'Aboh-Mbaise', 'Oyo', 'Akoko-West', 'Warri-Central', 'Cross-River',
#        'Jos-South', 'Onitsha-North', 'Osun', 'Ajeromi-Ifelodun',
#        'Kano-Municipal', 'Ife-Central', 'Ilorin-West', 'Lagelu-North',
#        'Owerri-Municipal', 'Nsit-Ubium', 'Udi-Agwu', 'Essien-Udim',
#        'Owerri-West', 'Ondo', 'Ogbmosho-South', 'Umuahia-South',
#        'ABULE-EGBA', 'Enugu-North', 'Ovia-SouthWest', 'Kebbi',
# ...

# %%
# Replace the entity, Joint gender, sex and not stated value in gender with NaN value
V_insurance["Gender"] = V_insurance["Gender"].replace('Entity', np.nan)
V_insurance["Gender"] = V_insurance["Gender"].replace('Joint Gender', np.nan)
V_insurance["Gender"] = V_insurance["Gender"].replace('SEX', np.nan)
V_insurance["Gender"] = V_insurance["Gender"].replace('NO GENDER', np.nan)
V_insurance["Gender"] = V_insurance["Gender"].replace('NOT STATED', np.nan)
V_insurance["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
# fill NaNs in all columns with the mode of the all columns
# Reconfirm that all columns has no NaNs again.
V_insurance['Gender'] = V_insurance['Gender'].fillna(V_insurance['Gender'].mode()[0])  
V_insurance['Car_Category'] = V_insurance['Car_Category'].fillna(V_insurance['Car_Category'].mode()[0])
V_insurance['Subject_Car_Colour'] = V_insurance['Subject_Car_Colour'].fillna(V_insurance['Subject_Car_Colour'].mode()[0])
V_insurance['Subject_Car_Make'] = V_insurance['Subject_Car_Make'].fillna(V_insurance['Subject_Car_Make'].mode()[0])
V_insurance['LGA_Name'] = V_insurance['LGA_Name'].fillna(V_insurance['LGA_Name'].mode()[0])
V_insurance['State'] = V_insurance['State'].fillna(V_insurance['State'].mode()[0])
V_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  object
#  2   Policy End Date         12079 non-null  object
#  3   Gender                  12079 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  object
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            12079 non-null  object
#  8   Subject_Car_Colour      12079 non-null  object
#  9   Subject_Car_Make        12079 non-null  object
#  10  LGA_Name                12079 non-null  object
#  11  State                   12079 non-null  object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %%
# Changing the Policy start date, End date and first transaction date to datetime data-type

V_insurance['Policy Start Date'] =  pd.to_datetime(V_insurance['Policy Start Date'])
V_insurance['Policy End Date'] =  pd.to_datetime(V_insurance['Policy End Date'])
V_insurance['First Transaction Date'] = pd.to_datetime(V_insurance['First Transaction Date'])

# %%
# Extracting the difference between both the policy start and end date
V_insurance['Policy Period'] = abs(V_insurance ['Policy End Date'] - V_insurance['Policy Start Date'])

# %%
# Converting the Policy Period to int type.
V_insurance['Policy Period'] = V_insurance['Policy Period'].dt.days.astype('int64')

# %%
V_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12079 entries, 0 to 12078
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12079 non-null  object
#  1   Policy Start Date       12079 non-null  datetime64[ns]
#  2   Policy End Date         12079 non-null  datetime64[ns]
#  3   Gender                  12079 non-null  object
#  4   Age                     12079 non-null  int64
#  5   First Transaction Date  12079 non-null  datetime64[ns]
#  6   No_Pol                  12079 non-null  int64
#  7   Car_Category            12079 non-null  object
#  8   Subject_Car_Colour      12079 non-null  object
#  9   Subject_Car_Make        12079 non-null  object
#  10  LGA_Name                12079 non-null  object
#  11  State                   12079 non-null  object
#  12  ProductName             12079 non-null  object
#  13  target                  12079 non-null  int64
# ...

# %%
# Reordering the columns to ensure the outcome is on the last column
column_names = ["ID","Policy Start Date","Policy End Date","Policy Period","Gender","Age","First Transaction Date", "No_Pol","Car_Category","Subject_Car_Colour","Subject_Car_Make","LGA_Name","State", "ProductName", "target"]
V_insurance = V_insurance.reindex(columns = column_names)

# %%
V_insurance
# Out:
#             ID Policy Start Date Policy End Date  Policy Period  Gender  Age  \
# 0      0040R73        2010-05-14      2011-05-13            364    Male   30
# 1      0046BNK        2010-11-29      2011-11-28            364  Female   79
# 2      005QMC3        2010-03-21      2011-03-20            364    Male   43
# 3      0079OHW        2010-08-21      2011-08-20            364    Male    2
# 4      00BRP63        2010-08-29      2010-12-31            124    Male   20
# ...        ...               ...             ...            ...     ...  ...
# 12074  ZZA1SES        2010-05-25      2011-05-24            364  Female   30
# 12075  ZZDAC3K        2010-10-03      2011-10-02            364  Female   59
# 12076  ZZIU2XC        2010-10-10      2011-10-08            363    Male   34
# 12077  ZZRQ1NF        2010-02-27      2011-02-26            364    Male  120
# 12078  ZZWRIIE        2010-07-01      2011-06-30            364  Female   46
#
# ...

# %%
V_insurance.describe()
# Out:
#        Policy Period           Age        No_Pol        target
# count   12079.000000  12079.000000  12079.000000  12079.000000
# mean      349.558076     42.234539      1.307227      0.120457
# std       214.752199     97.492565      0.733085      0.325509
# min        12.000000  -6099.000000      1.000000      0.000000
# 25%       364.000000     35.000000      1.000000      0.000000
# 50%       364.000000     41.000000      1.000000      0.000000
# 75%       364.000000     50.000000      1.000000      0.000000
# max     11139.000000    320.000000     10.000000      1.000000

# %%
V_insurance["Age"].unique()
# Out:
# array([   30,    79,    43,     2,    20,    37,    40,    71,    58,
#           45,    51,   120,    38,    81,    69,    31,    70,    34,
#            1,    41,    47,    36,    46,    48,    39,    63,    42,
#           27,    64,    50,    53,    33,    23,    32,    59,    60,
#           52,    54,    44,    11,    78,    28,    29,    57,    12,
#           65,    35,    73,    56,    55,    26,    49,    18,    14,
#           62,    25,    61,    72,    82,    67,     7,    10,    68,
#           21,    76,    24,    66,     3,    93,    22,    77,    19,
#           80,     9,     6,   -76,    -2,    89,    74,    75,    84,
#           16,    90,   140,     8,     5,    13,    86,    15,   320,
#          -12,    83,    85, -6099, -5939,     4,   -22,   144,   112,
#           17,     0,    88,   -27,    87,   133,   102,   -51,   128,
#          -26,   100], dtype=int64)

# %%
# Changing all negative numeric value to positive numeric
num = V_insurance["Age"]._get_numeric_data()
num [num < 1] = 1

# %%
# changing all age above 100 to 100
num = V_insurance["Age"]._get_numeric_data()
num [num > 100] = 100

# %%
V_insurance["Age"].unique() ## every age here is between 1 to 100
# Out:
# array([ 30,  79,  43,   2,  20,  37,  40,  71,  58,  45,  51, 100,  38,
#         81,  69,  31,  70,  34,   1,  41,  47,  36,  46,  48,  39,  63,
#         42,  27,  64,  50,  53,  33,  23,  32,  59,  60,  52,  54,  44,
#         11,  78,  28,  29,  57,  12,  65,  35,  73,  56,  55,  26,  49,
#         18,  14,  62,  25,  61,  72,  82,  67,   7,  10,  68,  21,  76,
#         24,  66,   3,  93,  22,  77,  19,  80,   9,   6,  89,  74,  75,
#         84,  16,  90,   8,   5,  13,  86,  15,  83,  85,   4,  17,  88,
#         87], dtype=int64)

# %%
V_insurance.describe()
# Out:
#        Policy Period           Age        No_Pol        target
# count   12079.000000  12079.000000  12079.000000  12079.000000
# mean      349.558076     42.931286      1.307227      0.120457
# std       214.752199     17.253900      0.733085      0.325509
# min        12.000000      1.000000      1.000000      0.000000
# 25%       364.000000     35.000000      1.000000      0.000000
# 50%       364.000000     41.000000      1.000000      0.000000
# 75%       364.000000     50.000000      1.000000      0.000000
# max     11139.000000    100.000000     10.000000      1.000000

# %%
V_insurance_corr = V_insurance.corr()
V_insurance_corr
# Out:
#                Policy Period       Age    No_Pol    target
# Policy Period       1.000000  0.003591 -0.019347 -0.022750
# Age                 0.003591  1.000000  0.108490 -0.028555
# No_Pol             -0.019347  0.108490  1.000000  0.074245
# target             -0.022750 -0.028555  0.074245  1.000000

# %%
#dropping id
V_insurance.drop(['ID'],axis = 1,inplace= True)

# %%
V_insurance
# Out:
#       Policy Start Date Policy End Date  Policy Period  Gender  Age  \
# 0            2010-05-14      2011-05-13            364    Male   30
# 1            2010-11-29      2011-11-28            364  Female   79
# 2            2010-03-21      2011-03-20            364    Male   43
# 3            2010-08-21      2011-08-20            364    Male    2
# 4            2010-08-29      2010-12-31            124    Male   20
# ...                 ...             ...            ...     ...  ...
# 12074        2010-05-25      2011-05-24            364  Female   30
# 12075        2010-10-03      2011-10-02            364  Female   59
# 12076        2010-10-10      2011-10-08            363    Male   34
# 12077        2010-02-27      2011-02-26            364    Male  100
# 12078        2010-07-01      2011-06-30            364  Female   46
#
#       First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0                 2010-05-14       1       Saloon              Black
# ...

# %% [markdown]
# # Data Visualization

# %%
V_insurance.hist(figsize=(15,16))
plt.show()

# %%
plt.figure(figsize =(12,8))

plt.bar(V_insurance['Age'], V_insurance['No_Pol'])

plt.xlabel('Age')
plt.ylabel('No_Pol') # The age between 20 and 40 has the highest number of policy
# Out:
# Text(0, 0.5, 'No_Pol')

# %%
plt.figure(figsize =(12,8))

plt.bar(V_insurance['Gender'], V_insurance['No_Pol'])

plt.xlabel('Gender')
plt.ylabel('No_Pol')
# Out:
# Text(0, 0.5, 'No_Pol')

# %%
V_insurance.plot(kind = 'box',subplots = True,layout= (3,2),sharex = False, figsize =(16,24))
plt.show()
